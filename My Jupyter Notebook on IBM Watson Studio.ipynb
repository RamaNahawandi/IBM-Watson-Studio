# %% [raw]
# Exercise 2 -

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [raw]
# Exercise 3 -

# %% [markdown]
# <strong >Rama Nahawandi</strong >
# <p>data analyst</p>

# %% [markdown]
# <p>In this homework assignment, I will be demonstrating my understanding of Python programming and Markdown syntax in HTML by creating a Jupyter Notebook. This assignment is a part of the course I am taking on Coursera, and it will help me practice the concepts covered in the lectures and readings.</p>

# %% [markdown]
# <i>I am interested in data science because it is a highly in-demand field that offers a wide range of opportunities to work with data and extract insights that can drive business decisions and improve outcomes. Additionally, data science can help me develop valuable skills in statistics, programming, and critical thinking that can be applied to a variety of industries.</i>

# %% [markdown]
# <h3>When you run this code, it will output 8, which is the result of adding a and b.</h3>

# %%
a = 5
b = 3
c = a + b
print(c)
# Out:
# 8

# %% [markdown]
# <hr>
#     <h1>List of fruits:</h1>
#     <ul>
#       <li>Apple</li>
#       <li>Orange</li>
#       <li>Banana</li>
#     </ul>
#     <h1>List of countries:</h1>
#     <ol>
#       <li>USA</li>
#       <li>Canada</li>
#       <li>France</li>
#     </ol>
#     <h1>Table of prices:</h1>
#
#
#
#
#    <table>
#   <tr>
#     <th>Header 1</th>
#     <th>Header 2</th>
#     <th>Header 3</th>
#   </tr>
#   <tr>
#     <td>Row 1, Column 1</td>
#     <td>Row 1, Column 2</td>
#     <td>Row 1, Column 3</td>
#   </tr>
#   <tr>
#     <td>Row 2, Column 1</td>
#     <td>Row 2, Column 2</td>
#     <td>Row 2, Column 3</td>
#   </tr>
#   <tr>
#     <td>Row 3, Column 1</td>
#     <td>Row 3, Column 2</td>
#     <td>Row 3, Column 3</td>
#   </tr>
# </table>

# %% [raw]
# # Exercise 4

# %% [markdown]
# <ul>
#   <li>Python</li>
#   <li>R</li>
#   <li>SQL</li>
#   <li>Java</li>
#   <li>Scala</li>
#   <li>Julia</li>
#   <li>Matlab</li>
#   <li>SAS</li>
# </ul>

# %% [raw]
# Exercise 5

# %% [markdown]
# <ul>
#   <li>Pandas</li>
#   <li>Numpy</li>
#   <li>Scikit-learn</li>
#   <li>TensorFlow</li>
#   <li>PyTorch</li>
#   <li>Matplotlib</li>
#   <li>Seaborn</li>
#   <li>ggplot</li>
# </ul>

# %% [markdown]
# Exercise 6-

# %% [markdown]
# <table>
#   <thead>
#     <tr>
#       <th>Tool</th>
#       <th>Purpose</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Python</td>
#       <td>General-purpose programming language for data analysis</td>
#     </tr>
#     <tr>
#       <td>R</td>
#       <td>Statistical computing language and environment</td>
#     </tr>
#     <tr>
#       <td>SQL</td>
#       <td>Query language for managing and analyzing relational data</td>
#     </tr>
#     <tr>
#       <td>Jupyter</td>
#       <td>Interactive computing environment for data science</td>
#     </tr>
#     <tr>
#       <td>Pandas</td>
#       <td>Data manipulation and analysis library for Python</td>
#     </tr>
#     <tr>
#       <td>Scikit-learn</td>
#       <td>Machine learning library for Python</td>
#     </tr>
#     <tr>
#       <td>TensorFlow</td>
#       <td>Open-source platform for building and deploying ML models</td>
#     </tr>
#     <tr>
#       <td>Tableau</td>
#       <td>Data visualization and business intelligence platform</td>
#     </tr>
#   </tbody>
# </table>

# %% [raw]
# Exercise 7 -

# %% [markdown]
# <p>Arithmetic expressions are mathematical operations that combine numbers and symbols to produce a result. In programming, arithmetic expressions are commonly used for calculations and data manipulation. Some common arithmetic operators include addition (+), subtraction (-), multiplication (*), and division (/). Here are some examples of arithmetic expressions:</p>
#
# <ul>
#   <li>2 + 3 = 5</li>
#   <li>6 - 4 = 2</li>
#   <li>5 * 7 = 35</li>
#   <li>10 / 2 = 5</li>
#   <li>9 % 4 = 1</li>
# </ul>

# %% [raw]
# Exercise 8 -

# %%
num1 = 5
num2 = 3
product = num1 * num2
print("The product of", num1, "and", num2, "is", product)


num3 = 7
num4 = 2
sum = num3 + num4
print("The sum of", num3, "and", num4, "is", sum)
# Out:
# The product of 5 and 3 is 15
# The sum of 7 and 2 is 9

# %% [raw]
# Exercise 9 -

# %%
# ask user for input
minutes = int(input("Enter the number of minutes: "))

# convert to hours and minutes
hours = minutes // 60
remaining_minutes = minutes % 60

# output the result
print(minutes, "minutes is equal to", hours, "hours and", remaining_minutes, "minutes.")
# Out:
# Enter the number of minutes: 120
# 120 minutes is equal to 2 hours and 0 minutes.

# %% [raw]
# Exercise 10

# %% [markdown]
# <h2>Objectives:</h2>
# <ul>
#   <li>Learn HTML basics</li>
#   <li>Understand CSS concepts</li>
#   <li>Build interactive web pages using JavaScript</li>
#   <li>Explore advanced web development topics</li>
# </ul>

# %% [raw]
# Exercise 11 -

# %% [markdown]
# <strong >Author:  Rama Nahawandi</strong >
# <p>data analyst</p>
